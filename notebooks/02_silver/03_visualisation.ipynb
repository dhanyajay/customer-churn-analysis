# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='customer_churn', data=df)
plt.title("Churn Distribution")
plt.show()

# %%
sns.boxplot(x='customer_churn', y='total_revenue', data=df)
plt.title("Revenue vs Churn")
plt.show()

# %%
sns.boxplot(x='customer_churn', y='total_agreements', data=df)
plt.show()

# %%
sns.boxplot(x='customer_churn', y='avg_unit_amount', data=df)
plt.show()

# %%
sns.histplot(df['total_revenue'], kde=True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
pd.crosstab(df['some_category'], df['customer_churn'], normalize='index')

# %%
sns.boxplot(x='customer_churn', y='revenue_per_agreement', data=df)
plt.show()
